# %%
#pandas --> package for data analayis
import pandas as pd
import numpy as np

# %%
#series, dataframe, panel
#series --> labelled 1-D array
series1 = pd.Series(np.array([13,4,2]))

# %%
type(series1)
# Out:
# pandas.core.series.Series

# %%
series1
# Out:
# 0    13
# 1     4
# 2     2
# dtype: int64

# %%
series2 = pd.Series([13,4,2],index=['a','b','c'])

# %%
series2
# Out:
# a    13
# b     4
# c     2
# dtype: int64

# %%
#dataframe --> 2-D labelled array, row and col index, tabular
df1 = pd.DataFrame([[1,"Ravi"],[2,"Shankar"],[3,"Rahul"],[4,"Rohan"]])

# %%
type(df1)
# Out:
# pandas.core.frame.DataFrame

# %%
df1 = pd.DataFrame([[1,"Ravi"],[2,"Sujith"],[3,"Rahul"],[4,"Rohan"]],index=['a','b','c','d'],columns=['Roll_No.','Name'])

# %%
df1
# Out:
#    Roll_No.        Name
# a         1        Ravi
# b         2      Sujith
# c         3  Hanumantha
# d         4       Rohan

# %%
#walmart sales :
walmart = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/sales_subset.csv')

# %%
type(walmart)
# Out:
# pandas.core.frame.DataFrame

# %%
#Display first 5 rows
walmart.head()
# Out:
#    Unnamed: 0  store type  ...  temperature_c fuel_price_usd_per_l  unemployment
# 0           0      1    A  ...       5.727778             0.679451         8.106
# 1           1      1    A  ...       8.055556             0.693452         8.106
# 2           2      1    A  ...      16.816667             0.718284         7.808
# 3           3      1    A  ...      22.527778             0.748928         7.808
# 4           4      1    A  ...      27.050000             0.714586         7.808
#
# [5 rows x 10 columns]

# %%
#Display last 5 rows
walmart.tail()
# Out:
#        Unnamed: 0  store  ... fuel_price_usd_per_l  unemployment
# 10769       10769     39  ...             0.834256         7.716
# 10770       10770     39  ...             0.887619         7.244
# 10771       10771     39  ...             0.911922         6.989
# 10772       10772     39  ...             0.860145         6.623
# 10773       10773     39  ...             0.955511         6.228
#
# [5 rows x 10 columns]

# %%
#Information, #samples a.k.a rows a.k.a. tuples
walmart.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10774 entries, 0 to 10773
# Data columns (total 10 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Unnamed: 0            10774 non-null  int64
#  1   store                 10774 non-null  int64
#  2   type                  10774 non-null  object
#  3   department            10774 non-null  int64
#  4   date                  10774 non-null  object
#  5   weekly_sales          10774 non-null  float64
#  6   is_holiday            10774 non-null  bool
#  7   temperature_c         10774 non-null  float64
#  8   fuel_price_usd_per_l  10774 non-null  float64
#  9   unemployment          10774 non-null  float64
# dtypes: bool(1), float64(4), int64(3), object(2)
# memory usage: 768.2+ KB

# %%
walmart.shape
# Out:
# (10774, 10)

# %%
#Descriptive Statistics
walmart.describe()
# Out:
#          Unnamed: 0         store  ...  fuel_price_usd_per_l  unemployment
# count  10774.000000  10774.000000  ...          10774.000000  10774.000000
# mean    5386.500000     15.441897  ...              0.749746      8.082009
# std     3110.330234     11.534511  ...              0.059494      0.624355
# min        0.000000      1.000000  ...              0.664129      3.879000
# 25%     2693.250000      4.000000  ...              0.708246      7.795000
# 50%     5386.500000     13.000000  ...              0.743381      8.099000
# 75%     8079.750000     20.000000  ...              0.781421      8.360000
# max    10773.000000     39.000000  ...              1.107674      9.765000
#
# [8 rows x 7 columns]

# %%
#numpy array
walmart.values
# Out:
# array([[0, 1, 'A', ..., 5.727777777777778, 0.6794508388787476, 8.106],
#        [1, 1, 'A', ..., 8.055555555555555, 0.6934519642522211, 8.106],
#        [2, 1, 'A', ..., 16.81666666666667, 0.7182841488768721, 7.808],
#        ...,
#        [10771, 39, 'A', ..., 27.288888888888888, 0.911922354513778,
#         6.989],
#        [10772, 39, 'A', ..., 25.644444444444442, 0.8601446078496121,
#         6.622999999999998],
#        [10773, 39, 'A', ..., 22.25, 0.9555107636953459, 6.228]],
#       dtype=object)

# %%
covid_data = pd.read_csv('https://covid.ourworldindata.org/data/owid-covid-data.csv')

# %%
covid_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 126246 entries, 0 to 126245
# Data columns (total 65 columns):
#  #   Column                                   Non-Null Count   Dtype
# ---  ------                                   --------------   -----
#  0   iso_code                                 126246 non-null  object
#  1   continent                                120533 non-null  object
#  2   location                                 126246 non-null  object
#  3   date                                     126246 non-null  object
#  4   total_cases                              119356 non-null  float64
#  5   new_cases                                119352 non-null  float64
#  6   new_cases_smoothed                       118338 non-null  float64
#  7   total_deaths                             108413 non-null  float64
#  8   new_deaths                               108566 non-null  float64
#  9   new_deaths_smoothed                      118338 non-null  float64
# ...

# %%
#Sort a dataframe
walmart_sorted = walmart.sort_values('weekly_sales',ascending=False)
walmart_sorted.sort_values('temperature_c',inplace=True)
walmart_sorted
# Out:
#       Unnamed: 0  store type  ...  temperature_c fuel_price_usd_per_l  unemployment
# 4830        4830     13    A  ...      -8.366667             0.763722         7.470
# 4506        4506     13    A  ...      -8.366667             0.763722         7.470
# 4950        4950     13    A  ...      -8.366667             0.763722         7.470
# 5028        5028     13    A  ...      -8.366667             0.763722         7.470
# 5323        5323     13    A  ...      -8.366667             0.763722         7.470
# ...          ...    ...  ...  ...            ...                  ...           ...
# 4476        4476     10    B  ...      33.827778             0.786705         9.199
# 3598        3598     10    B  ...      33.827778             0.786705         9.199
# 4126        4126     10    B  ...      33.827778             0.786705         9.199
# 3874        3874     10    B  ...      33.827778             0.786705         9.199
# ...

# %%
#Filtering rows based on some condition
#when were the cases where temperature was less than 0 ??
temp_negative = walmart['temperature_c'] < 0
unique_temp_negative = pd.unique(walmart[temp_negative]['store']) #subsetting

# %%
unique_temp_negative
# Out:
# array([ 4, 13, 14, 19, 20, 27])

# %%
walmart[temp_negative][['store','date']] #subsetting
# Out:
#       store        date
# 2315      4  2010-02-12
# 2492      4  2010-02-12
# 4495     13  2010-02-05
# 4505     13  2010-12-03
# 4506     13  2011-01-07
# ...     ...         ...
# 8938     27  2010-02-05
# 8950     27  2010-02-05
# 8962     27  2010-02-05
# 8974     27  2010-02-05
# 8986     27  2010-02-05
#
# [750 rows x 2 columns]

# %%
walmart.sort_values(['type','weekly_sales'],ascending=[False,False])
# Out:
#       Unnamed: 0  store type  ...  temperature_c fuel_price_usd_per_l  unemployment
# 4271        4271     10    B  ...      12.411111             0.782478         9.765
# 4281        4281     10    B  ...      10.650000             0.803348         9.003
# 4272        4272     10    B  ...      13.288889             0.760023         9.765
# 3595        3595     10    B  ...      17.588889             0.815235         9.524
# 4277        4277     10    B  ...      30.072222             0.825010         9.199
# ...          ...    ...  ...  ...            ...                  ...           ...
# 7719        7719     20    A  ...       1.927778             0.804668         7.484
# 517          517      1    A  ...      14.327778             0.704547         8.106
# 3217        3217      6    A  ...      20.505556             0.734399         7.092
# 1420        1420      2    A  ...      28.605556             0.697415         8.099
# ...

# %%
walmart[['fuel_price_usd_per_l','weekly_sales']].apply(np.mean)
# Out:
# fuel_price_usd_per_l        0.749746
# weekly_sales            23843.950149
# dtype: float64

# %%
walmart
# Out:
#        Unnamed: 0  store  ... fuel_price_usd_per_l  unemployment
# 0               0      1  ...             0.679451         8.106
# 1               1      1  ...             0.693452         8.106
# 2               2      1  ...             0.718284         7.808
# 3               3      1  ...             0.748928         7.808
# 4               4      1  ...             0.714586         7.808
# ...           ...    ...  ...                  ...           ...
# 10769       10769     39  ...             0.834256         7.716
# 10770       10770     39  ...             0.887619         7.244
# 10771       10771     39  ...             0.911922         6.989
# 10772       10772     39  ...             0.860145         6.623
# 10773       10773     39  ...             0.955511         6.228
#
# [10774 rows x 10 columns]

# %%
walmart.loc[5,['store','weekly_sales']] #indexing along with slicing
# Out:
# store                 1
# weekly_sales    16333.1
# Name: 5, dtype: object

# %%
walmart.iloc[5,[1,5]]
# Out:
# store                 1
# weekly_sales    16333.1
# Name: 5, dtype: object

# %%
walmart.iloc[5:10,5:7]
# Out:
#    weekly_sales  is_holiday
# 5      16333.14       False
# 6      17508.41       False
# 7      16241.78       False
# 8      20094.19       False
# 9      34238.88       False

# %%
# Preprocessing : Finding missing values
covid_data.isna()
covid_data.isna().sum()
covid_data['total_deaths'].isna().sum()
# Out:
# 17833

# %%
#Preprocessing :
covid_new = covid_data['total_deaths'].fillna(0)

# %%
covid_new.isna().sum()
# Out:
# 0

# %%
#group by method
#df.groupby("Col1")["col_value"].aggfunc()
walmart.groupby('type')['weekly_sales'].mean()# Average weekly sales of all the stores
# Out:
# type
# A    23674.667242
# B    25696.678370
# Name: weekly_sales, dtype: float64

# %%
walmart.groupby('department')['unemployment'].max().head(5)
# Out:
# department
# 1    9.765
# 2    9.765
# 3    9.765
# 4    9.765
# 5    9.765
# Name: unemployment, dtype: float64

# %%
walmart.groupby('type')[['weekly_sales','temperature_c']].mean()
# Out:
#       weekly_sales  temperature_c
# type
# A     23674.667242      15.231333
# B     25696.678370      21.211327

# %%
walmart.groupby('type')[['weekly_sales','temperature_c']].agg([min,max,np.mean])
# Out:
#      weekly_sales                          temperature_c
#               min        max          mean           min        max       mean
# type
# A         -1098.0  293966.05  23674.667242     -8.366667  33.300000  15.231333
# B          -798.0  232558.51  25696.678370      6.350000  33.827778  21.211327

# %%
walmart.groupby(['type','department'])[['weekly_sales','temperature_c']].agg([min,max,np.mean])
# Out:
#                 weekly_sales             ... temperature_c
#                          min        max  ...           max       mean
# type department                          ...
# A    1               9446.29  149743.97  ...     32.388889  15.258754
#      2              42431.88   93677.66  ...     32.388889  15.258754
#      3               6150.20   69512.63  ...     32.388889  15.258754
#      4              28762.65   66912.92  ...     32.388889  15.258754
#      5              11665.55  103531.25  ...     32.388889  15.258754
# ...                      ...        ...  ...           ...        ...
# B    94               -12.60    1903.68  ...     33.827778  21.379167
#      95             60655.66   94868.27  ...     33.827778  21.216204
#      96              8348.61   10576.00  ...     33.827778  21.216204
#      97              5064.61    6720.96  ...     33.827778  21.216204
#      98                -2.25    1075.30  ...     33.827778  21.163426
#
# [157 rows x 6 columns]

# %%
#pivot table
#df.pivot_table(values='col_value',index='col1',aggfunc=[np.mean])
walmart.pivot_table(values='weekly_sales',index='type',columns='department',aggfunc=[np.mean,max,np.sum,np.var])
# Out:
#                     mean                 ...           var
# department            1              2   ...            98             99
# type                                     ...
# A           30961.725379   67600.158788  ...  1.407711e+07  405331.295212
# B           44050.626667  112958.526667  ...  1.534983e+05            NaN
#
# [2 rows x 320 columns]

# %%
walmart
# Out:
#        Unnamed: 0  store  ... fuel_price_usd_per_l  unemployment
# 0               0      1  ...             0.679451         8.106
# 1               1      1  ...             0.693452         8.106
# 2               2      1  ...             0.718284         7.808
# 3               3      1  ...             0.748928         7.808
# 4               4      1  ...             0.714586         7.808
# ...           ...    ...  ...                  ...           ...
# 10769       10769     39  ...             0.834256         7.716
# 10770       10770     39  ...             0.887619         7.244
# 10771       10771     39  ...             0.911922         6.989
# 10772       10772     39  ...             0.860145         6.623
# 10773       10773     39  ...             0.955511         6.228
#
# [10774 rows x 10 columns]

# %%
#Explicit Indices
walmart_new = walmart.set_index('store')

# %%
walmart_new
# Out:
#        Unnamed: 0 type  ...  fuel_price_usd_per_l unemployment
# store                   ...
# 1               0    A  ...              0.679451        8.106
# 1               1    A  ...              0.693452        8.106
# 1               2    A  ...              0.718284        7.808
# 1               3    A  ...              0.748928        7.808
# 1               4    A  ...              0.714586        7.808
# ...           ...  ...  ...                   ...          ...
# 39          10769    A  ...              0.834256        7.716
# 39          10770    A  ...              0.887619        7.244
# 39          10771    A  ...              0.911922        6.989
# 39          10772    A  ...              0.860145        6.623
# 39          10773    A  ...              0.955511        6.228
#
# [10774 rows x 9 columns]

# %%
walmart_new.reset_index(inplace=True)

# %%
walmart_new
# Out:
#        store  Unnamed: 0  ... fuel_price_usd_per_l  unemployment
# 0          1           0  ...             0.679451         8.106
# 1          1           1  ...             0.693452         8.106
# 2          1           2  ...             0.718284         7.808
# 3          1           3  ...             0.748928         7.808
# 4          1           4  ...             0.714586         7.808
# ...      ...         ...  ...                  ...           ...
# 10769     39       10769  ...             0.834256         7.716
# 10770     39       10770  ...             0.887619         7.244
# 10771     39       10771  ...             0.911922         6.989
# 10772     39       10772  ...             0.860145         6.623
# 10773     39       10773  ...             0.955511         6.228
#
# [10774 rows x 10 columns]

# %%
walmart_new = walmart_new.set_index(['store','type'])

# %%
walmart_new.sort_index(ascending=[False])
# Out:
#             Unnamed: 0  department  ... fuel_price_usd_per_l  unemployment
# store type                          ...
# 39    A           9899           1  ...             0.679451         8.554
#       A           9900           1  ...             0.693452         8.554
#       A           9901           1  ...             0.718284         8.464
#       A           9902           1  ...             0.748928         8.464
#       A           9903           1  ...             0.714586         8.464
# ...                ...         ...  ...                  ...           ...
# 1     A            896          99  ...             0.854861         7.866
#       A            897          99  ...             0.834256         7.866
#       A            898          99  ...             0.887619         7.348
#       A            899          99  ...             1.027894         7.143
#       A            900          99  ...             0.955511         6.573
#
# [10774 rows x 8 columns]

# %%
#Data Visualisation using pandas
import matplotlib.pyplot as plt
#pandas is built on top of numpy and matplotlib

# %%
new_data = walmart.groupby('type')['weekly_sales'].agg([np.sum])

# %%
new_data.plot(kind='barh')
plt.show()

# %%
#histogram : data distribution
walmart['temperature_c'].hist()
plt.plot()
# Out:
# []
